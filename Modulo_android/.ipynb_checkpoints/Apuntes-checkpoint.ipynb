# %% [markdown]
# # Apuntes modulo Android
# ### Profesor: Carlos Andrés Palma Suárez
#
#
# #### Primera Clase:
# Una larga charla introductoria de dispositivos móviles y sus sistemas operativos, incluyendo la posición en el mercado de los mismos. Luego una explicación detallada del funcionamiento de Scrum.
#
#    * ##### Tarea:
#    Realizar una consulta de 10 distintos entornos de desarrollo para dispositivos móviles.
#
#    * ##### Solución:
#        1. **[Kivy:](https://kivy.org/#home)** Python library for rapid development of applications that make use of innovative user interfaces, such as multi-touch apps.
#        2. **[Appcelerator:](http://www.appcelerator.com/):** Everything you need to create great, native mobile apps—all from a single JavaScript code base.
#        3. ** [PhoneGAp:](http://phonegap.com/)** Easily create apps using the web technologies you know and love: HTML, CSS, and JavaScript.
#        4. **[jQuery Mobile:](https://jquerymobile.com/)** jQuery Mobile is a HTML5-based user interface system designed to make responsive web sites and apps that are accessible on all smartphone, tablet and desktop devices.
#        5. ** [iBuild App:](http://es.ibuildapp.com)** iBuildApp es una plataforma muy fácil de usar para crear aplicaciones móviles. La plataforma permite a las empresas crear y publicar su iPhone y Android app en cuestión de minutos.
#        6. **[Sencha Touch:](https://www.sencha.com/products/touch/#overview)** The leading cross-platform mobile web application framework based on HTML5 and JavaScript for creating universal mobile apps.
#        7. **[Xamarin:](https://www.xamarin.com/)** Deliver native iOS, Android, and Windows apps using existing skills, teams, and code.
#        8. **[appery.io:](https://appery.io)** Appery.io is a rapid development, integration and deployment platform for delivering cross-device apps in the enterprise
#        9. **[Rhonmobile:](https://rms.rhomobile.com/)** Build Native Apps in the Cloud
#        10. **[Basic 4 Android:](https://www.b4x.com/)**"Thanks to B4A and you guys with your help I got a permanent job developing Android apps for a Company, and I sold my app (see CNC Sheet) to another company."
#        11. **Carbide.c++**
#        12. **XCode:**
#        13. **App Inventor: **
#        14. **Ruboto: **
#
# #### Segunda Clase 21- 04-2017:
# * Conceptos básicos:
#     * API: Liberia
#     * SDK: Kit para Desarrollo de Software (Librería + Compilación) viene el motor incluido.
#     * IDE: Entorno de Desarrollo Integrado, ventanilla para programar
#     *
# * Se usara corona, java, AndoridStudio,
# * Corona no trae entorno de desarrollo
# * Tener en cuenta en que API desarrollar si en 4, 6, 7. Se recomienda una mas o menos vieja, para no perder clientes.
# * Actividad: tiene vista y la vista tiene componentes. Esta presentada por la pantalla que se seta viendo.
# * Actividad, implica un montón de elementos ademas de la vista
# * el simulador de corona es mas rápido que el de Android
# * Lua es el lenguaje que usa corona
# * Appinventor es incluso mas rápido que corona
# * app inventor usa scarsh
# * AndroidStudio: genera un emulador con TODO ANDROID entero, igualmente appinventor, aunque app inventor usa una versión vieja de Android
#
# ##### Tarea:
# Idear propuesta de aplicación, Por ejemplo una calculadora, algo que tenga interacción con botones que hagan funciones matemáticas, algo que use una fórmula sencilla, aunque podría ser algo mas pesado, es un tipo de mini proyecto y tenerlo para la siguiente clase osea mañana sábado.
#
# #### Tercera Clase 22-04-2017:
# * **Pensamientos Iniciales:** 9 :17 am acaban de llegar dos personas hasta el momento solo era yo y el profe y el andaba hablando por celular, que flojera. si se va a seguir perdiendo así, no aguanta. pero lo pelan el resto piden que pal sábado y ahora dicen ñaaññaña los sábados aveces tenemos parciales, quien los entiende. me la pelan quiero programar y este man no se ve como muy buen profesor que digamos. Carlos opina cuadrar horario, pero no están todos asi que no se pude decidir ajjjjaajaj y yo tengo todo el día todos los días me les voy a pagar todo XD. 9:22 ya tengo mi maquina virtual chateare un rato a ver, pues aun no inicia la clase. 9:26 empezó la clase.
#
# ----------------------------------
# Al parecer según entiendo se hablara primero de requisitos, requerimientos,etc, etc. todo antes de ponerse a programar.
# Consejo:
# * Documentar
# * Realizar pasos de ing del software
# * Hacer historia de usuario, se hará en Excel (me la pela microcosas :3)
#
# ##### Historia de Usuario:
# Cada fila es una historia de usuario
# que voy a hacer y como lo voy a evaluar
#
# pila de producto||||
# -|-
# **titulo**|**funcionalidad**|**criterios de aceptación**|**Observaciones**
# saludo| Quiero que cuando escriba mi nombre, y presione el botón me salude el celular|1. Si escribo un nombre y presiono el botón aparecerá un mensaje con el saludo. <br> 2.Si presiono el botón y no hay escrito un nombre debe aparecer un mensaje que hace falta llenar el dato del nombre.| Debe aparecer una caja de texto y un botón.
#
# Nota: Pequeño ejemplo de historia de usuario.
#
# primero se trabajara en [appinventor](http://appinventor.mit.edu/explore/front.html)
#
# * Las fuentes serifadas ayudan en tipos de lecturas largas. las serifas no sirven en documentos de impresión entonces se usan las letras san serif. y el otro tipo de fuente es la monospace, las tipo consola.
#
# PDTA: El cucho ta chateando :3 (soy un quejetas)
#
# hint text: Texto defecto en las cajas de texto (marca de agua)
#
# Se realiza una primera aplicación de app invenotr que consiste en un boton que saluda
# ![screen](images/appInventor_holaMundo_screen.png)
# ![code](images/appInventor_holaMundo.png) <i style="color:red">Pdta: hay un pequeño error no es lbnombre si no txnombre</i>
#
# ###### Tarea:
# Desarrollar una app móvil cosa pequeña con botones y otros componentes, documentar, hacer la pila de la aplicación, al module se sube la documentación y la apk
#
# ###### Solución:
# Se plantea una pequeña aplicación capas de rotar una imagen, no se plantea el echo de que cargue una imagen o después la guarde unicamente que una imagen en pantalla la pueda rotar según se mueva un slider.
#
# **titulo**|**Funcionalidad**|**Criterio de aceptación**
# ----------|-----------------|--------------------------
# Giro Imagen| la imagen debe girar según el movimiento del scroll|la imagen debe de girar con el movimiento del scroll
#
# ![tarea uno uno](images/primera_tarea_uno.png)
# ![tarea uno dos](images/primera_tarea_dos.png)
#
# #### Cuarta Clase 28-04-2017:
# mierda 6:25 esta calificando la tarea :3; anda explicando el entorno de Android, hay gente que no sabe java, da una breve explicación de java y clases, etc.
#
# En el método onCleate de java en Android estudio es donde se hacen las referencias de los elementos del código con los elementos de la vista.
#
# Configurar Android en casa aunque mierda puto pc feo, el cao es que hacer app para calcular el cuadrado en androidStudio.
#
# #### Quinta Clase 29-04-2017:
# Perdí los primeros apuntes de la clase dado que me dio flojera hacer el commit en Geomatica, pero bueno no fue nada raro, lo de siempre gente llegando tarde, aunque esta vez la clase fue mas entretenida, se programo en Corona el cual maneja un lenguaje de programación llamado lua, es script, el desarrollo es algo engorroso respecto a la interfaces gráfica pues todo toca a punta de cuadrados y otras figuras, pero de por si es muy amigable trabajar ahí, corona permite la programación tanto para Android como para ios, aunque toca estar programando en un MAC para poder exportar el archivo de instalación de ios.
#
# Se deja la tarea de realiza una aplicación con un nivel mayor de dificultad, planeo instalar AndroidStudio y corona y realizar la app en ambas plataformas a ver que tal me va:
# 1. Primero andorid estudio se instalo con ubuntu-make, una herramienta que ayuda a instlar varias herramientas para desarrolladores
# 2. Corona se planea instalar con playonlinux con un [video](https://www.youtube.com/watch?v=3tQDTcVSlUg) que encontré, pero al parece no puedo entrar a la pagina para conseguir el sdk
#
# ###### Instalar Android Studio:
# >`sudo add-apt-repository ppa:ubuntu-desktop/ubuntu-make`<br>
# >`sudo apt-get update`<br>
# >`sudo apt-get install ubuntu-make`<br>
# >`sudo umake android android-studio`
#
# ###### Instalar Corona
# * Instalar PlayOnLuinux
# * Descargar el sdk de Corona
# * Durante la instalación de corona en playonlinux instalar los siguientes paquetes:
#     * corefonts
#     * vcrun2013
#     * wmp10
#
# * Nota: En este verraco pc no puedo trabajar por falta de tarjeta de video actualizada
#
# Andorid estudio esta funcionando por alguna razón corona no, sigue diciendo que por la tarjeta de video. no se que sera el error de corona se veía chebere de programar pero pues me dedicare a Andorid studio en /AndroidStudioProyect se encuentra el código de la aplicación realizada para esta tareas.
#
# ###### Documentación.
#
# Titulo|Funcionalidad|Aceptación
# -|-
# Bienvenida|Mostrar una Bienvenida a la Aplicación| Debe de existir un pequeño y breve texto que de la bienvenida a la app y explique brevemente el funcionamiento de la misma
# Valor Monto| Mostrar el monto acumulado del dinero| Debe de haber un texto de mediano tamaño que indique el valor exacto del monto acumulado en la cuenta, dicho texto debe cambiar de color entre rojo y verde dependiendo si el usuario tiene deuda o no
# Ingreso Monto| Textfield para el ingreso del monto | deberá haber un textfield donde se pueda agregar el valor del monto a sumar o restar del monto actual
# Combos Ingreso y Egreso| seleccionar si el monto a agregar sera un saldo positivo o negativo para el monto actual| deberá haber un combox donde se pueda seleccionar entre ingresar o extraer valor al monto
# Calcular| debe ingresar o extraer dinero de la cuenta| debe de haber un botón el cual al ser espichado agregue y egrese dinero de la cuenta según el monto ingresado en el textfield

# %% [markdown]
# #### Sexta Clase 05-05-2017:
# Una mierda llego y que nos cambiaron de salas, nos cambian a la sala mac y no tiene nada configurado y aparte de eso apenas 3 o 4 pcs tienen internet, asi que esta clase y la clase de mañana tocara usar appInventor y esa mierda es una mierda malparidos de geomtica que nos tienen en un ricon solo por que es gratis, si nos piden un proyecto y no nos ofrecen una buena sala para ver nestras clases pdta: ojala nadie lea esto XD jajaajaaj el caso es que quemierda y pa colmo la gente llega tarde 6:42 y no hemos empesado la clase, aunque bueno anda caliicando la tarea de mis compañeros y eso no es malo pero malditasea quiero programr al 100.
#
# ###### Peqeña idea hacer un boton en la app para cambiar de actividad
#
# 7:00 pm no hemos programado, hemos hablado de varias cosas pero nada en concreto aunque por ai va a mostrar com pasar de activiti
#
# * se vieron cosas en lua y andorid tanto para cambiar de pantallas y pasar variables entre pantallas
#
# ### TAREA:
# hacer esas actvidades tanto para andorid y lua.
# malditasea lua no me va a quedar grande seria maquina virtual de win7

# %% [markdown]
# #### Septima Clase:
# No hay internet y no hay ni mierda :3 8:42 suepuesmente hoy sera pra hacer un plan de proyecto, dure 18 min resolviendo un sudoku y llego un reero de gente que ni puta idea, esto esta una mierda y so las 9:03 a las y 15 llego uno de los muchachos el otro barbudo; las y 22 y nada que se hace nada, el man me la pela deberia empezar a trabajar conmigo y que los que llegan tarde que se jodan, pero se pone a esperar, sabe que tengo andoridStudio aqui instalado

# %% [markdown]
# ##### Ocatava Clase 12-05-2017:
# Pues no se hizo nada el solo mostro otra vez una pagina de un tutorial de como usar la camara fin.
#
# ##### Novena Clase 13-05-2017:
# Pues llegue temprano pero no ha iniciado son las 9:09, nadie a llegado solo yo y el profe, y no reviso la tarea y eso que le dije que ya la tenia echa, 9:28 no ha empezado la clase.
# 9:40 empieza esta monda con la explciaicon de lso proyectos que queire gemoatica
# nos mostro los proyectos y mierda estan pesados eso requeria tiempo y yo digo mierda, tendre qeu hablar con gustavo de eso.

# %% [markdown]
# #### Decima Clase 19-05-2017:
# Hoy fui yo el que llego tarde pero menos mal, el profe estaba comiendo algo asi que no me perdi de nada :3, son las 6:25 y la clase hace dos minutos inicio, esta dando una explicacion de los proyectos ya que la clase pasada no habia venido carlos y el otro barbas.
# Los requisitos son:
# * Verificables
# * trasables, trasabilidad lleva un codigo
# *
# El profe esta haceindo unosarreglos a un documento para hacer la parte de los requisitos de las aplicaciones :3
#
# QUE PERDEDERA DE TIEMPOOOOOOOOOOOOO

# %% [markdown]
# ##### Onceaba clase 26-05-2017:
# No fui a clase, callo un palo de agua re paila.
#
# ##### Doceaba calse 27-05-2017:
# Llege super temprano a la, a las 8:30 a las 9 llego el profe y son las 9:21 y no ha llegado nadie mas y el igual sigue esperando en vez de empezar la clase, igual no tiene nada preparado, no a logrado hacer lo que dijo que nos iba a enserñar referente a la camara, meintras estoy haciendo lo del documento que quede de realizar con gallego. 9 :41 nada de clase :3 sigue trabajando el en lo suyo y yo en lo mio, hasta le hice una encuesta ya. 9:47 lego gallego y carlos.
# y nada que inicia clase XD. malaprido gallego a mi lado y no trabaja a duras penas me vio trabajdno en eso y abrio docs y ya. a eso de las 10:15 paso por donde todos y nos corrigio un par de cosas. hay uq e arreglar el de casos de uso.
#
# ###### Treceava clase 2-06-2017:
# Pues empezo tarde como siempre a mas de las y media, explico el codigo de la camara que hizo y que todavia tenaia la de bugs y ya 0 programaacion de parte nuestra, pasara el codigo de la camara habra que revisarlo despues.
