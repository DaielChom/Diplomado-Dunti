# %% [markdown]
# # Bitácora - 07:  Practica ARDG
# ## Practica Autodenominada Recolección de Datos para Geomatica
#
# ### Seleccion entre ONA y Kobotoolbox
# App|Instalacion|Version|Infraestrucutra|estetica|librerias|funcionalidades|Documentacion o Comunidad|
# -|-|-
# ONA| Complicadita|ultima version| Maneja formalarios, proyectos, usuarios, organizaciones, tiene muchos mas servicios para el manejo de los formularios y sus datos| es mucho mas bonita que kobootolbox||* deja tener varios pryectos dentro de los cuales puede tener varios formularios y dichos formularios pueden ser compartidos con varios usuarios, las opciones y servicios que tiene el formualrio son mas robustas y en mayor cantidad que en kobotoolbox | una documantacion olvidada y muy desactualizada lo que genera que su intalacion sea complicada y las personas que no sepan usar github para buscar en los issues alguna ayuda les es dificil encontrar en la WEB informacion o blogs sobre la misma, hay un grupo en google groups con un total de 213 miembros, github con varios seguidores (Ona Community)[https://groups.google.com/forum/#!forum/ona-community], una wiki descuidada en github
# Koboto| Sencilla|version estable (2015)|Pues al parecer tiene todo lo que pedia Geomatica, maneja su base de datos y tales| ES bontia, agradable a la vista y simple, no es recargada ni nada| |* Crear forms, crear proyectos, guardar librerias de preguntas, crear y editar usuarios en los proyectos creados se puede ver la base de datos, analisis de los mismos, se pueden descargar, revisar la galeria y descargarla, importar datos tanto del navegador como del movil. no encuentro como podria tener varios vormularios en un solo proyecto, pues si no estoy mal asi lo tienen en geomaica | una persona que no sepa de github encuentra mas facilmente informacion de koboto ya que tiene una seccion de preguntas en su pagina web la cual hace las busquedas mas facil, grupo de google de 819 miembros, github con pocos seguidores (Kobo User)[https://groups.google.com/forum/#!forum/kobo-users] una wiki mas detallada
#
#
# Kobotoolbox:
# kobo
# kobo
#
# Onadata
# onadata
# onadata
#
# Notas: al probar ona en el pc me pedia que el usuario al registarse confirmra la cuenta ocn el correo, mientras que en la pagina web pude crear mi cuneta sin necesidad de la misma.
#
# Ona permite varios proyectos y dentro de cada prouecto se peuden crear varios formularios en kobotoolbox cada poryecto tiene un unico formulariio
#
# en ona se puede crear una organizacion y sino estoy mal varios usuarios pueden interactuar en un mismo proyecto o formulario
#
# en ona manejo mi propio perfil de usuario con cierta informacion y puedo ver a otros usuaios
#
# ona deja compartir los formularios y dar ciertos niveles de permisos a otro usuarios.
#
# mi voto es para ONA es mucho mas robusta mas pensada para las organizaciones
